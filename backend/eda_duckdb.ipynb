# %% [markdown]
# # 🦆 Automated Exploratory Data Analysis with DuckDB
#
# This notebook provides automated EDA for:
# - **CSV files**
# - **Parquet files**
# - **DuckDB databases**
#
# Just set your file path below and run all cells!

# %% [markdown]
# ## Configuration
#
# Set your data source path below. Supports:
# - `.csv` files
# - `.parquet` files
# - `.duckdb` / `.db` database files

# %%
# ============================================================
# 📁 SET YOUR DATA SOURCE HERE
# ============================================================

DATA_SOURCE = "/home/Alberto.Barcelos/Downloads/Crime_Data_from_2020_to_Present.csv"  # Change this to your file path

# Examples:
# DATA_SOURCE = "data/sales.csv"
# DATA_SOURCE = "data/events.parquet"
# DATA_SOURCE = "analytics.duckdb"

# %% [markdown]
# ## Setup & Imports

# %%
import duckdb
from pathlib import Path
from IPython.display import display, HTML, Markdown
import warnings
warnings.filterwarnings('ignore')

def styled_header(text: str, emoji: str = "📊") -> None:
    """Display a styled section header."""
    display(HTML(f"""
    <div style="
        background: linear-gradient(135deg, #1a1a2e 0%, #16213e 100%);
        padding: 12px 20px;
        border-radius: 8px;
        margin: 20px 0 10px 0;
        border-left: 4px solid #e94560;
    ">
        <h3 style="color: #eee; margin: 0; font-weight: 600;">
            {emoji} {text}
        </h3>
    </div>
    """))

def styled_stat(label: str, value: str) -> None:
    """Display a styled statistic."""
    display(HTML(f"""
    <div style="
        display: inline-block;
        background: #1a1a2e;
        padding: 8px 16px;
        border-radius: 6px;
        margin: 4px;
    ">
        <span style="color: #888; font-size: 12px;">{label}</span><br>
        <span style="color: #e94560; font-size: 18px; font-weight: bold;">{value}</span>
    </div>
    """))

print("✅ Setup complete!")
# Out:
# ✅ Setup complete!

# %% [markdown]
# ## EDA Functions

# %%
class DuckDBExplorer:
    """Automated Exploratory Data Analysis with DuckDB."""
    
    def __init__(self, source: str):
        """Initialize the explorer with a data source."""
        self.source = source
        self.path = Path(source)
        self.con = None
        self.tables = []
        self._setup_connection()
    
    def _setup_connection(self) -> None:
        """Setup DuckDB connection based on source type."""
        suffix = self.path.suffix.lower()
        
        if suffix in ('.duckdb', '.db'):
            # Connect to existing DuckDB database
            self.con = duckdb.connect(str(self.path), read_only=True)
            self.tables = [row[0] for row in self.con.execute("SHOW TABLES").fetchall()]
            print(f"📂 Connected to DuckDB database: {self.path.name}")
            print(f"   Found {len(self.tables)} table(s): {', '.join(self.tables)}")
        else:
            # CSV or Parquet - create in-memory connection with view
            self.con = duckdb.connect()
            self.con.execute(f"CREATE VIEW data AS SELECT * FROM '{self.source}'")
            self.tables = ['data']
            print(f"📂 Loaded file: {self.path.name}")
    
    def overview(self, table: str = None) -> None:
        """Display high-level overview of the data."""
        tables_to_analyze = [table] if table else self.tables
        
        for tbl in tables_to_analyze:
            styled_header(f"Overview: {tbl}", "📋")
            
            # Basic counts
            row_count = self.con.execute(f"SELECT COUNT(*) FROM {tbl}").fetchone()[0]
            col_count = len(self.con.execute(f"DESCRIBE {tbl}").fetchall())
            
            display(HTML(f"""
            <div style="display: flex; gap: 20px; flex-wrap: wrap;">
                <div style="background: #1a1a2e; padding: 15px 25px; border-radius: 8px; text-align: center;">
                    <div style="color: #888; font-size: 12px;">ROWS</div>
                    <div style="color: #e94560; font-size: 24px; font-weight: bold;">{row_count:,}</div>
                </div>
                <div style="background: #1a1a2e; padding: 15px 25px; border-radius: 8px; text-align: center;">
                    <div style="color: #888; font-size: 12px;">COLUMNS</div>
                    <div style="color: #0f94d2; font-size: 24px; font-weight: bold;">{col_count}</div>
                </div>
            </div>
            """))
    
    def schema(self, table: str = None) -> None:
        """Display schema/column information."""
        tables_to_analyze = [table] if table else self.tables
        
        for tbl in tables_to_analyze:
            styled_header(f"Schema: {tbl}", "🏗️")
            schema_df = self.con.execute(f"DESCRIBE {tbl}").fetchdf()
            display(schema_df.style.set_properties(**{
                'background-color': '#1a1a2e',
                'color': '#eee',
                'border-color': '#333'
            }))
    
    def sample(self, table: str = None, n: int = 5) -> None:
        """Display sample rows."""
        tables_to_analyze = [table] if table else self.tables
        
        for tbl in tables_to_analyze:
            styled_header(f"Sample Data: {tbl} (first {n} rows)", "👀")
            sample_df = self.con.execute(f"SELECT * FROM {tbl} LIMIT {n}").fetchdf()
            display(sample_df)
    
    def summary(self, table: str = None) -> None:
        """Display statistical summary using DuckDB's SUMMARIZE."""
        tables_to_analyze = [table] if table else self.tables
        
        for tbl in tables_to_analyze:
            styled_header(f"Statistical Summary: {tbl}", "📈")
            summary_df = self.con.execute(f"SUMMARIZE {tbl}").fetchdf()
            display(summary_df)
    
    def nulls(self, table: str = None) -> None:
        """Analyze null values in each column."""
        tables_to_analyze = [table] if table else self.tables
        
        for tbl in tables_to_analyze:
            styled_header(f"Null Analysis: {tbl}", "🕳️")
            
            row_count = self.con.execute(f"SELECT COUNT(*) FROM {tbl}").fetchone()[0]
            cols = self.con.execute(f"DESCRIBE {tbl}").fetchall()
            
            null_data = []
            for col_name, col_type, *_ in cols:
                null_count = self.con.execute(
                    f'SELECT COUNT(*) FROM {tbl} WHERE "{col_name}" IS NULL'
                ).fetchone()[0]
                pct = (null_count / row_count * 100) if row_count > 0 else 0
                null_data.append({
                    'Column': col_name,
                    'Type': col_type,
                    'Null Count': null_count,
                    'Null %': f"{pct:.1f}%",
                    'Completeness': f"{100-pct:.1f}%"
                })
            
            import pandas as pd
            null_df = pd.DataFrame(null_data)
            
            # Highlight columns with nulls
            def highlight_nulls(row):
                if row['Null Count'] > 0:
                    return ['background-color: #3d1a1a'] * len(row)
                return [''] * len(row)
            
            display(null_df.style.apply(highlight_nulls, axis=1))
    
    def uniques(self, table: str = None, max_categories: int = 20) -> None:
        """Analyze unique values and cardinality."""
        tables_to_analyze = [table] if table else self.tables
        
        for tbl in tables_to_analyze:
            styled_header(f"Cardinality Analysis: {tbl}", "🔢")
            
            row_count = self.con.execute(f"SELECT COUNT(*) FROM {tbl}").fetchone()[0]
            cols = self.con.execute(f"DESCRIBE {tbl}").fetchall()
            
            cardinality_data = []
            for col_name, col_type, *_ in cols:
                unique_count = self.con.execute(
                    f'SELECT COUNT(DISTINCT "{col_name}") FROM {tbl}'
                ).fetchone()[0]
                pct = (unique_count / row_count * 100) if row_count > 0 else 0
                
                # Determine cardinality type
                if unique_count == row_count:
                    card_type = "🔑 Unique (potential key)"
                elif unique_count <= 2:
                    card_type = "🔘 Binary"
                elif unique_count <= max_categories:
                    card_type = "📊 Low (categorical)"
                else:
                    card_type = "📈 High (continuous)"
                
                cardinality_data.append({
                    'Column': col_name,
                    'Unique Values': unique_count,
                    'Uniqueness %': f"{pct:.1f}%",
                    'Type': card_type
                })
            
            import pandas as pd
            card_df = pd.DataFrame(cardinality_data)
            display(card_df)
    
    def value_counts(self, column: str, table: str = None, top_n: int = 10) -> None:
        """Show value distribution for a specific column."""
        tbl = table or self.tables[0]
        styled_header(f"Value Counts: {column} (top {top_n})", "📊")
        
        query = f'''
            SELECT "{column}" as value, COUNT(*) as count
            FROM {tbl}
            GROUP BY "{column}"
            ORDER BY count DESC
            LIMIT {top_n}
        '''
        df = self.con.execute(query).fetchdf()
        
        total = self.con.execute(f"SELECT COUNT(*) FROM {tbl}").fetchone()[0]
        df['percentage'] = (df['count'] / total * 100).round(2).astype(str) + '%'
        display(df)
    
    def correlations(self, table: str = None) -> None:
        """Calculate correlations between numeric columns."""
        tbl = table or self.tables[0]
        styled_header(f"Numeric Correlations: {tbl}", "🔗")
        
        # Get numeric columns
        cols = self.con.execute(f"DESCRIBE {tbl}").fetchall()
        numeric_cols = [
            col[0] for col in cols 
            if any(t in col[1].upper() for t in ['INT', 'FLOAT', 'DOUBLE', 'DECIMAL', 'NUMERIC', 'BIGINT'])
        ]
        
        if len(numeric_cols) < 2:
            print("⚠️ Not enough numeric columns for correlation analysis")
            return
        
        # Build correlation matrix using DuckDB
        corr_data = []
        for col1 in numeric_cols:
            row = {}
            for col2 in numeric_cols:
                corr = self.con.execute(f'''
                    SELECT CORR("{col1}", "{col2}") FROM {tbl}
                ''').fetchone()[0]
                row[col2] = round(corr, 3) if corr is not None else None
            corr_data.append(row)
        
        import pandas as pd
        corr_df = pd.DataFrame(corr_data, index=numeric_cols)
        
        # Style the correlation matrix
        def color_corr(val):
            if val is None:
                return ''
            if val > 0.7:
                return 'background-color: #1a472a; color: white'
            elif val < -0.7:
                return 'background-color: #4a1a1a; color: white'
            return ''
        
        display(corr_df.style.applymap(color_corr))
    
    def full_report(self, table: str = None) -> None:
        """Run complete EDA analysis."""
        styled_header("FULL EDA REPORT", "🦆")
        display(HTML(f"<p style='color: #888;'>Source: <code>{self.source}</code></p>"))
        
        self.overview(table)
        self.schema(table)
        self.sample(table)
        self.summary(table)
        self.nulls(table)
        self.uniques(table)
        self.correlations(table)
        
        styled_header("Analysis Complete!", "✅")
    
    def query(self, sql: str):
        """Run a custom SQL query."""
        styled_header("Custom Query", "🔍")
        result = self.con.execute(sql).fetchdf()
        display(result)
        return result
    
    def close(self) -> None:
        """Close the database connection."""
        if self.con:
            self.con.close()
            print("🔒 Connection closed")

print("✅ DuckDBExplorer class loaded!")
# Out:
# ✅ DuckDBExplorer class loaded!

# %% [markdown]
# ## 🚀 Run Full EDA Report
#
# Execute the cell below to run a complete automated analysis on your data source.

# %%
# Initialize the explorer with your data source
eda = DuckDBExplorer(DATA_SOURCE)

# Run the full automated EDA report
eda.full_report()
# Out:
# 📂 Loaded file: Crime_Data_from_2020_to_Present.csv
#     <div style="
#         background: linear-gradient(135deg, #1a1a2e 0%, #16213e 100%);
#         padding: 12px 20px;
#         border-radius: 8px;
#         margin: 20px 0 10px 0;
#         border-left: 4px solid #e94560;
#     ">
#         <h3 style="color: #eee; margin: 0; font-weight: 600;">
#             🦆 FULL EDA REPORT
#         </h3>
#     </div>
# <p style='color: #888;'>Source: <code>/home/Alberto.Barcelos/Downloads/Crime_Data_from_2020_to_Present.csv</code></p>
#     <div style="
#         background: linear-gradient(135deg, #1a1a2e 0%, #16213e 100%);
#         padding: 12px 20px;
#         border-radius: 8px;
#         margin: 20px 0 10px 0;
#         border-left: 4px solid #e94560;
#     ">
#         <h3 style="color: #eee; margin: 0; font-weight: 600;">
#             📋 Overview: data
#         </h3>
#     </div>
#             <div style="display: flex; gap: 20px; flex-wrap: wrap;">
#                 <div style="background: #1a1a2e; padding: 15px 25px; border-radius: 8px; text-align: center;">
#                     <div style="color: #888; font-size: 12px;">ROWS</div>
#                     <div style="color: #e94560; font-size: 24px; font-weight: bold;">1,003,448</div>
#                 </div>
#                 <div style="background: #1a1a2e; padding: 15px 25px; border-radius: 8px; text-align: center;">
#                     <div style="color: #888; font-size: 12px;">COLUMNS</div>
#                     <div style="color: #0f94d2; font-size: 24px; font-weight: bold;">28</div>
#                 </div>
#             </div>
#     <div style="
#         background: linear-gradient(135deg, #1a1a2e 0%, #16213e 100%);
#         padding: 12px 20px;
#         border-radius: 8px;
#         margin: 20px 0 10px 0;
#         border-left: 4px solid #e94560;
#     ">
#         <h3 style="color: #eee; margin: 0; font-weight: 600;">
#             🏗️ Schema: data
#         </h3>
#     </div>
# <style type="text/css">
# #T_4f987_row0_col0, #T_4f987_row0_col1, #T_4f987_row0_col2, #T_4f987_row0_col3, #T_4f987_row0_col4, #T_4f987_row0_col5, #T_4f987_row1_col0, #T_4f987_row1_col1, #T_4f987_row1_col2, #T_4f987_row1_col3, #T_4f987_row1_col4, #T_4f987_row1_col5, #T_4f987_row2_col0, #T_4f987_row2_col1, #T_4f987_row2_col2, #T_4f987_row2_col3, #T_4f987_row2_col4, #T_4f987_row2_col5, #T_4f987_row3_col0, #T_4f987_row3_col1, #T_4f987_row3_col2, #T_4f987_row3_col3, #T_4f987_row3_col4, #T_4f987_row3_col5, #T_4f987_row4_col0, #T_4f987_row4_col1, #T_4f987_row4_col2, #T_4f987_row4_col3, #T_4f987_row4_col4, #T_4f987_row4_col5, #T_4f987_row5_col0, #T_4f987_row5_col1, #T_4f987_row5_col2, #T_4f987_row5_col3, #T_4f987_row5_col4, #T_4f987_row5_col5, #T_4f987_row6_col0, #T_4f987_row6_col1, #T_4f987_row6_col2, #T_4f987_row6_col3, #T_4f987_row6_col4, #T_4f987_row6_col5, #T_4f987_row7_col0, #T_4f987_row7_col1, #T_4f987_row7_col2, #T_4f987_row7_col3, #T_4f987_row7_col4, #T_4f987_row7_col5, #T_4f987_row8_col0, #T_4f987_row8_col1, #T_4f987_row8_col2, #T_4f987_row8_col3, #T_4f987_row8_col4, #T_4f987_row8_col5, #T_4f987_row9_col0, #T_4f987_row9_col1, #T_4f987_row9_col2, #T_4f987_row9_col3, #T_4f987_row9_col4, #T_4f987_row9_col5, #T_4f987_row10_col0, #T_4f987_row10_col1, #T_4f987_row10_col2, #T_4f987_row10_col3, #T_4f987_row10_col4, #T_4f987_row10_col5, #T_4f987_row11_col0, #T_4f987_row11_col1, #T_4f987_row11_col2, #T_4f987_row11_col3, #T_4f987_row11_col4, #T_4f987_row11_col5, #T_4f987_row12_col0, #T_4f987_row12_col1, #T_4f987_row12_col2, #T_4f987_row12_col3, #T_4f987_row12_col4, #T_4f987_row12_col5, #T_4f987_row13_col0, #T_4f987_row13_col1, #T_4f987_row13_col2, #T_4f987_row13_col3, #T_4f987_row13_col4, #T_4f987_row13_col5, #T_4f987_row14_col0, #T_4f987_row14_col1, #T_4f987_row14_col2, #T_4f987_row14_col3, #T_4f987_row14_col4, #T_4f987_row14_col5, #T_4f987_row15_col0, #T_4f987_row15_col1, #T_4f987_row15_col2, #T_4f987_row15_col3, #T_4f987_row15_col4, #T_4f987_row15_col5, #T_4f987_row16_col0, #T_4f987_row16_col1, #T_4f987_row16_col2, #T_4f987_row16_col3, #T_4f987_row16_col4, #T_4f987_row16_col5, #T_4f987_row17_col0, #T_4f987_row17_col1, #T_4f987_row17_col2, #T_4f987_row17_col3, #T_4f987_row17_col4, #T_4f987_row17_col5, #T_4f987_row18_col0, #T_4f987_row18_col1, #T_4f987_row18_col2, #T_4f987_row18_col3, #T_4f987_row18_col4, #T_4f987_row18_col5, #T_4f987_row19_col0, #T_4f987_row19_col1, #T_4f987_row19_col2, #T_4f987_row19_col3, #T_4f987_row19_col4, #T_4f987_row19_col5, #T_4f987_row20_col0, #T_4f987_row20_col1, #T_4f987_row20_col2, #T_4f987_row20_col3, #T_4f987_row20_col4, #T_4f987_row20_col5, #T_4f987_row21_col0, #T_4f987_row21_col1, #T_4f987_row21_col2, #T_4f987_row21_col3, #T_4f987_row21_col4, #T_4f987_row21_col5, #T_4f987_row22_col0, #T_4f987_row22_col1, #T_4f987_row22_col2, #T_4f987_row22_col3, #T_4f987_row22_col4, #T_4f987_row22_col5, #T_4f987_row23_col0, #T_4f987_row23_col1, #T_4f987_row23_col2, #T_4f987_row23_col3, #T_4f987_row23_col4, #T_4f987_row23_col5, #T_4f987_row24_col0, #T_4f987_row24_col1, #T_4f987_row24_col2, #T_4f987_row24_col3, #T_4f987_row24_col4, #T_4f987_row24_col5, #T_4f987_row25_col0, #T_4f987_row25_col1, #T_4f987_row25_col2, #T_4f987_row25_col3, #T_4f987_row25_col4, #T_4f987_row25_col5, #T_4f987_row26_col0, #T_4f987_row26_col1, #T_4f987_row26_col2, #T_4f987_row26_col3, #T_4f987_row26_col4, #T_4f987_row26_col5, #T_4f987_row27_col0, #T_4f987_row27_col1, #T_4f987_row27_col2, #T_4f987_row27_col3, #T_4f987_row27_col4, #T_4f987_row27_col5 {
#   background-color: #1a1a2e;
#   color: #eee;
#   border-color: #333;
# }
# </style>
# <table id="T_4f987">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f987_level0_col0" class="col_heading level0 col0" >column_name</th>
#       <th id="T_4f987_level0_col1" class="col_heading level0 col1" >column_type</th>
#       <th id="T_4f987_level0_col2" class="col_heading level0 col2" >null</th>
#       <th id="T_4f987_level0_col3" class="col_heading level0 col3" >key</th>
#       <th id="T_4f987_level0_col4" class="col_heading level0 col4" >default</th>
#       <th id="T_4f987_level0_col5" class="col_heading level0 col5" >extra</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f987_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f987_row0_col0" class="data row0 col0" >DR_NO</td>
#       <td id="T_4f987_row0_col1" class="data row0 col1" >BIGINT</td>
#       <td id="T_4f987_row0_col2" class="data row0 col2" >YES</td>
#       <td id="T_4f987_row0_col3" class="data row0 col3" >None</td>
#       <td id="T_4f987_row0_col4" class="data row0 col4" >None</td>
#       <td id="T_4f987_row0_col5" class="data row0 col5" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4f987_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4f987_row1_col0" class="data row1 col0" >Date Rptd</td>
#       <td id="T_4f987_row1_col1" class="data row1 col1" >TIMESTAMP</td>
#       <td id="T_4f987_row1_col2" class="data row1 col2" >YES</td>
#       <td id="T_4f987_row1_col3" class="data row1 col3" >None</td>
#       <td id="T_4f987_row1_col4" class="data row1 col4" >None</td>
#       <td id="T_4f987_row1_col5" class="data row1 col5" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4f987_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4f987_row2_col0" class="data row2 col0" >DATE OCC</td>
#       <td id="T_4f987_row2_col1" class="data row2 col1" >TIMESTAMP</td>
#       <td id="T_4f987_row2_col2" class="data row2 col2" >YES</td>
#       <td id="T_4f987_row2_col3" class="data row2 col3" >None</td>
#       <td id="T_4f987_row2_col4" class="data row2 col4" >None</td>
#       <td id="T_4f987_row2_col5" class="data row2 col5" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4f987_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4f987_row3_col0" class="data row3 col0" >TIME OCC</td>
#       <td id="T_4f987_row3_col1" class="data row3 col1" >VARCHAR</td>
#       <td id="T_4f987_row3_col2" class="data row3 col2" >YES</td>
#       <td id="T_4f987_row3_col3" class="data row3 col3" >None</td>
#       <td id="T_4f987_row3_col4" class="data row3 col4" >None</td>
#       <td id="T_4f987_row3_col5" class="data row3 col5" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4f987_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4f987_row4_col0" class="data row4 col0" >AREA</td>
#       <td id="T_4f987_row4_col1" class="data row4 col1" >VARCHAR</td>
#       <td id="T_4f987_row4_col2" class="data row4 col2" >YES</td>
#       <td id="T_4f987_row4_col3" class="data row4 col3" >None</td>
#       <td id="T_4f987_row4_col4" class="data row4 col4" >None</td>
#       <td id="T_4f987_row4_col5" class="data row4 col5" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4f987_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4f987_row5_col0" class="data row5 col0" >AREA NAME</td>
#       <td id="T_4f987_row5_col1" class="data row5 col1" >VARCHAR</td>
#       <td id="T_4f987_row5_col2" class="data row5 col2" >YES</td>
#       <td id="T_4f987_row5_col3" class="data row5 col3" >None</td>
#       <td id="T_4f987_row5_col4" class="data row5 col4" >None</td>
#       <td id="T_4f987_row5_col5" class="data row5 col5" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4f987_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4f987_row6_col0" class="data row6 col0" >Rpt Dist No</td>
#       <td id="T_4f987_row6_col1" class="data row6 col1" >VARCHAR</td>
#       <td id="T_4f987_row6_col2" class="data row6 col2" >YES</td>
#       <td id="T_4f987_row6_col3" class="data row6 col3" >None</td>
#       <td id="T_4f987_row6_col4" class="data row6 col4" >None</td>
#       <td id="T_4f987_row6_col5" class="data row6 col5" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4f987_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4f987_row7_col0" class="data row7 col0" >Part 1-2</td>
#       <td id="T_4f987_row7_col1" class="data row7 col1" >BIGINT</td>
#       <td id="T_4f987_row7_col2" class="data row7 col2" >YES</td>
#       <td id="T_4f987_row
#     <div style="
#         background: linear-gradient(135deg, #1a1a2e 0%, #16213e 100%);
#         padding: 12px 20px;
#         border-radius: 8px;
#         margin: 20px 0 10px 0;
#         border-left: 4px solid #e94560;
#     ">
#         <h3 style="color: #eee; margin: 0; font-weight: 600;">
#             👀 Sample Data: data (first 5 rows)
#         </h3>
#     </div>
#        DR_NO  Date Rptd   DATE OCC TIME OCC AREA   AREA NAME Rpt Dist No  \
# 0  190326475 2020-03-01 2020-03-01     2130   07    Wilshire        0784
# 1  200106753 2020-02-09 2020-02-08     1800   01     Central        0182
# 2  200320258 2020-11-11 2020-11-04     1700   03   Southwest        0356
# 3  200907217 2023-05-10 2020-03-10     2037   09    Van Nuys        0964
# 4  200412582 2020-09-09 2020-09-09     0630   04  Hollenbeck        0413
#
#    Part 1-2  Crm Cd                               Crm Cd Desc  ... Status  \
# 0         1     510                          VEHICLE - STOLEN  ...     AA
# 1         1     330                     BURGLARY FROM VEHICLE  ...     IC
# 2         1     480                             BIKE - STOLEN  ...     IC
# 3         1     343  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)  ...     IC
# 4         1     510                          VEHICLE - STOLEN  ...     IC
#
#     Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0  Adult Arrest      510      998      <NA>     <NA>
# 1   Invest Cont      330      998      <NA>     <NA>
# 2   Invest Cont      480     <NA>      <NA>     <NA>
# 3   Invest Cont      343     <NA>      <NA>     <NA>
# 4   Invest Cont      510     <NA>      <NA>     <NA>
#
#                                    LOCATION Cross Street      LAT       LON
# 0   1900 S  LONGWOOD                     AV         None  34.0375 -118.3506
# 1   1000 S  FLOWER                       ST         None  34.0444 -118.2628
# 2   1400 W  37TH                         ST         None  34.0210 -118.3002
# 3  14000    RIVERSIDE                    DR         None  34.1576 -118.4387
# 4                          200 E  AVENUE 28         None  34.0820 -118.2130
#
# [5 rows x 28 columns]
#     <div style="
#         background: linear-gradient(135deg, #1a1a2e 0%, #16213e 100%);
#         padding: 12px 20px;
#         border-radius: 8px;
#         margin: 20px 0 10px 0;
#         border-left: 4px solid #e94560;
#     ">
#         <h3 style="color: #eee; margin: 0; font-weight: 600;">
#             📈 Statistical Summary: data
#         </h3>
#     </div>
#        column_name column_type                                       min  \
# 0            DR_NO      BIGINT                                       817
# 1        Date Rptd   TIMESTAMP                       2020-01-01 00:00:00
# 2         DATE OCC   TIMESTAMP                       2020-01-01 00:00:00
# 3         TIME OCC     VARCHAR                                      0001
# 4             AREA     VARCHAR                                        01
# 5        AREA NAME     VARCHAR                               77th Street
# 6      Rpt Dist No     VARCHAR                                      0101
# 7         Part 1-2      BIGINT                                         1
# 8           Crm Cd      BIGINT                                       110
# 9      Crm Cd Desc     VARCHAR                                     ARSON
# 10         Mocodes     VARCHAR                                      0100
# 11        Vict Age      BIGINT                                        -4
# 12        Vict Sex     VARCHAR                                         -
# 13    Vict Descent     VARCHAR                                         -
# 14       Premis Cd      BIGINT                                       101
# 15     Premis Desc     VARCHAR  7TH AND METRO CENTER (NOT LINE SPECIFIC)
# 16  Weapon Used Cd      BIGINT                                       101
# 17     Weapon Desc     VARCHAR          AIR PISTOL/REVOLVER/RIFLE/BB GUN
# 18          Status     VARCHAR                                        AA
# 19     Status Desc     VARCHAR                              Adult Arrest
# 20        Crm Cd 1      BIGINT                                       110
# 21        Crm Cd 2      BIGINT                                       210
# 22        Crm Cd 3      BIGINT                                       310
# 23        Crm Cd 4      BIGINT                                       821
# 24        LOCATION     VARCHAR                                00    17TH
# 25    Cross Street     VARCHAR           10                           FY
# 26             LAT      DOUBLE                                       0.0
# 27             LON      DOUBLE                                 -118.6676
#
#                                 max  approx_unique  \
# 0                         249928885        1324249
# 1               2024-12-21 00:00:00           2115
# 2               2024-12-21 00:00:00           2115
# 3                              2359           1649
# 4                                21             21
# 5                          Wilshire             21
# 6                              2199           1805
# 7                                 2              2
# 8                               956            148
# 9        WEAPONS POSSESSION/BOMBING            140
# 10                   9999 2004 0910         312910
# 11                              120            106
# 12                                X              5
# 13                                Z             19
# 14                              976            467
# 15      YARD (RESIDENTIAL/BUSINESS)            351
# 16                              516             86
# 17                    VERBAL THREAT             90
# 18                               JO              5
# 19                              UNK              6
# 20                              956            148
# 21                              999            122
# 22                              999             43
# 23                              999              6
# 24  ZOO                          DR          92438
# 25  ZUNIGA                       LN          13183
# 26                          34.3343           5586
# 27                              0.0           6665
#
#                            avg                 std  \
# 0            220185515.9817868  13169630.316388726
# 1   2022-05-24 10:56:48.707576                None
# 2   2022-05-12 07:53:05.958814                None
# 3                         None                None
# 4                         None                None
# 5                         None                None
# 6                         None                None
# 7           1.4005259863988966  0.4900052651739671
# 8            500.2210418477091   205.3108756269528
# 9                         None                None
# 10                        None                None
# 11          28.913324855896867  21.995382238306156
# 12                        None                None
# 13                        None                None
# 14          305.58455680105874  219.30489122643957
# 15                        None                None
# 16           363.9267469584887  123.74132632948518
# 17                        None                None
# 18                        None                None
# 19                        None                None
# 20          499.98124246963187   205.1112591958521
# 21           958.1182325877485  110.36480208619129
# 22            984.022030237581  52.340476149782475
# 23                   991.21875  27.069850123602198
# 24                        None                None
# 25                        None                None
# 26           33.99809729751689  1.6119417110745982
# 27         -118.09045798745989   5.586664867774897
#
#                            q25                         q50  \
# 0                    210640509                   220934962
# 1   2021-04-23 13:15:28.402058   2022-06-06 19:48:32.66019
# 2   2021-04-07 18:26:07.544415  2022-05-25 16:52:59.898157
# 3                         None                        None
# 4                         None                        None
# 5                         None                        None
# 6                         None                        None
# 7                            1                           1
# 8                          331                         442
# 9                         None                        None
# 10                        None                        None
# 11                           0                          30
# 12                        None                        None
# 13                        None                        None
# 14                         101                         203
# 15                        None                        None
# 16                         310                         400
# 17                        None                        None
# 18                        None                        None
# 19                        None                        None
# 20                         331                         442
# 21                         998                         998
# 22                         998                         998
# 23                         998                         998
# 24                        None                        None
# 25                        None                        None
# 26           34.01470966825938           34.05888500900401
# 27         -118.43012822552123         -118.32285988586816
#
#                            q75    count  null_percentage
# 0                    231097187  1003448             0.00
# 1   2023-07-01 19:46:26.733421  1003448             0.00
# 2   2023-06-20 01:08:04.293488  1003448             0.00
# 3                         None  1003448             0.00
# 4                         None  1003448             0.00
# 5                         None  1003448             0.00
# 6                         None  1003448             0.00
# 7                            2  1003448             0.00
# 8                          626  1003448             0.00
# 9                         None  1003448             0.00
# 10                        None  1003448            15.10
# 11                          44  1003448             0.00
# 12                        None  1003448            14.41
# 13                        None  1003448            14.41
# 14                         501  1003448             0.00
# 15                        None  1003448             0.06
# 16                         400  1003448            67.40
# 17                        None  1003448            67.40
# 18                        None  1003448             0.00
# 19                        None  1003448             0.00
# 20                         626  1003448             0.00
# 21                         998  1003448            93.11
# 22                         998  1003448            99.77
# 23                         998  1003448            99.99
# 24                        None  1003448             0.00
# 25                        None  1003448            84.64
# 26           34.16421119403443  1003448             0.00
# 27         -118.27422494585016  1003448             0.00
#     <div style="
#         background: linear-gradient(135deg, #1a1a2e 0%, #16213e 100%);
#         padding: 12px 20px;
#         border-radius: 8px;
#         margin: 20px 0 10px 0;
#         border-left: 4px solid #e94560;
#     ">
#         <h3 style="color: #eee; margin: 0; font-weight: 600;">
#             🕳️ Null Analysis: data
#         </h3>
#     </div>
# <style type="text/css">
# #T_897f4_row10_col0, #T_897f4_row10_col1, #T_897f4_row10_col2, #T_897f4_row10_col3, #T_897f4_row10_col4, #T_897f4_row12_col0, #T_897f4_row12_col1, #T_897f4_row12_col2, #T_897f4_row12_col3, #T_897f4_row12_col4, #T_897f4_row13_col0, #T_897f4_row13_col1, #T_897f4_row13_col2, #T_897f4_row13_col3, #T_897f4_row13_col4, #T_897f4_row14_col0, #T_897f4_row14_col1, #T_897f4_row14_col2, #T_897f4_row14_col3, #T_897f4_row14_col4, #T_897f4_row15_col0, #T_897f4_row15_col1, #T_897f4_row15_col2, #T_897f4_row15_col3, #T_897f4_row15_col4, #T_897f4_row16_col0, #T_897f4_row16_col1, #T_897f4_row16_col2, #T_897f4_row16_col3, #T_897f4_row16_col4, #T_897f4_row17_col0, #T_897f4_row17_col1, #T_897f4_row17_col2, #T_897f4_row17_col3, #T_897f4_row17_col4, #T_897f4_row18_col0, #T_897f4_row18_col1, #T_897f4_row18_col2, #T_897f4_row18_col3, #T_897f4_row18_col4, #T_897f4_row20_col0, #T_897f4_row20_col1, #T_897f4_row20_col2, #T_897f4_row20_col3, #T_897f4_row20_col4, #T_897f4_row21_col0, #T_897f4_row21_col1, #T_897f4_row21_col2, #T_897f4_row21_col3, #T_897f4_row21_col4, #T_897f4_row22_col0, #T_897f4_row22_col1, #T_897f4_row22_col2, #T_897f4_row22_col3, #T_897f4_row22_col4, #T_897f4_row23_col0, #T_897f4_row23_col1, #T_897f4_row23_col2, #T_897f4_row23_col3, #T_897f4_row23_col4, #T_897f4_row25_col0, #T_897f4_row25_col1, #T_897f4_row25_col2, #T_897f4_row25_col3, #T_897f4_row25_col4 {
#   background-color: #3d1a1a;
# }
# </style>
# <table id="T_897f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_897f4_level0_col0" class="col_heading level0 col0" >Column</th>
#       <th id="T_897f4_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_897f4_level0_col2" class="col_heading level0 col2" >Null Count</th>
#       <th id="T_897f4_level0_col3" class="col_heading level0 col3" >Null %</th>
#       <th id="T_897f4_level0_col4" class="col_heading level0 col4" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_897f4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_897f4_row0_col0" class="data row0 col0" >DR_NO</td>
#       <td id="T_897f4_row0_col1" class="data row0 col1" >BIGINT</td>
#       <td id="T_897f4_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_897f4_row0_col3" class="data row0 col3" >0.0%</td>
#       <td id="T_897f4_row0_col4" class="data row0 col4" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_897f4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_897f4_row1_col0" class="data row1 col0" >Date Rptd</td>
#       <td id="T_897f4_row1_col1" class="data row1 col1" >TIMESTAMP</td>
#       <td id="T_897f4_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_897f4_row1_col3" class="data row1 col3" >0.0%</td>
#       <td id="T_897f4_row1_col4" class="data row1 col4" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_897f4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_897f4_row2_col0" class="data row2 col0" >DATE OCC</td>
#       <td id="T_897f4_row2_col1" class="data row2 col1" >TIMESTAMP</td>
#       <td id="T_897f4_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_897f4_row2_col3" class="data row2 col3" >0.0%</td>
#       <td id="T_897f4_row2_col4" class="data row2 col4" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_897f4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_897f4_row3_col0" class="data row3 col0" >TIME OCC</td>
#       <td id="T_897f4_row3_col1" class="data row3 col1" >VARCHAR</td>
#       <td id="T_897f4_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_897f4_row3_col3" class="data row3 col3" >0.0%</td>
#       <td id="T_897f4_row3_col4" class="data row3 col4" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_897f4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_897f4_row4_col0" class="data row4 col0" >AREA</td>
#       <td id="T_897f4_row4_col1" class="data row4 col1" >VARCHAR</td>
#       <td id="T_897f4_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_897f4_row4_col3" class="data row4 col3" >0.0%</td>
#       <td id="T_897f4_row4_col4" class="data row4 col4" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_897f4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_897f4_row5_col0" class="data row5 col0" >AREA NAME</td>
#       <td id="T_897f4_row5_col1" class="data row5 col1" >VARCHAR</td>
#       <td id="T_897f4_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_897f4_row5_col3" class="data row5 col3" >0.0%</td>
#       <td id="T_897f4_row5_col4" class="data row5 col4" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_897f4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_897f4_row6_col0" class="data row6 col0" >Rpt Dist No</td>
#       <td id="T_897f4_row6_col1" class="data row6 col1" >VARCHAR</td>
#       <td id="T_897f4_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_897f4_row6_col3" class="data row6 col3" >0.0%</td>
#       <td id="T_897f4_row6_col4" class="data row6 col4" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_897f4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_897f4_row7_col0" class="data row7 col0" >Part 1-2</td>
#       <td id="T_897f4_row7_col1" class="data row7 col1" >BIGINT</td>
#       <td id="T_897f4_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_897f4_row7_col3" class="data row7 col3" >0.0%</td>
#       <td id="T_897f4_row7_col4" class="data row7 col4" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_897f4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_897f4_row8_col0" class="data row8 col0" >Crm Cd</td>
#       <td id="T_897f4_row8_col1" class="data row8 col1" >BIGINT</td>
#       <td id="T_897f4_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_897f4_row8_col3" class="data row8 col3" >0.0%</td>
#       <td id="T_897f4_row8_col4" class="data row8 col4" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_897f4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_897f4_row9_col0" class="data row9 col0" >Crm Cd Desc</td>
#       <td id="T_897f4_row9_col1" class="data row9 col1" >VARCHAR</td>
#       <td id="T_897f4_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_897f4_row9_col3" class="data row9 col3" >0.0%</td>
#       <td id="T_897f4_row9_col4" class="data row9 col4" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_897f4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_897f4_row10_col0" class="data row10 col0" >Mocodes</td>
#       <td id="T_897f4_row10_col1" class="data row10 col1" >VARCHAR</td>
#       <td id="T_897f4_row10_col2" class="data row10 col2" >151567</td>
#       <td id="T_897f4_row10_col3" class="data row10 col3" >15.1%</td>
#       <td id="T_897f4_row10_col4" class="data row10 col4" >84.9%</td>
#     </tr>
#     <tr>
#       <th id="T_897f4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_897f4_row11_col0" class="data row11 col0" >Vict Age</td>
#       <td id="T_897f4_row11_col1" class="data row11 col1" >BIGINT</td>
#       <td id="T_897f4_row11_col2" class="data row11 col2" >0</td>
#       <td id="T_897f4_row11_col3" class="data row11 col3" >0.0%</td>
#       <td id="T_897f4_row11_col4" class="data row11 col4" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_897f4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_897f4_row12_col0" class="data row12 col0" >Vict Sex</td>
#       <td id="T_897f4_row12_col1" class="data row12 col1" >VARCHAR</td>
#       <td id="T_897f4_row12_col2" class="data row12 col2" >144592</td>
#       <td id="T_897f4_row12_col3" class="data row12 col3" >14.4%</td>
#       <td id="T_897f4_row12_col4" class="data row12 col4" >85.6%</td>
#     </tr>
#     <tr>
#       <th id="T_897f4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_897f4_row13_col0" class="data row13 col0" >Vict Descent</td>
#       <td id="T_897f4_row13_col1" class="data row13 col1" >VARCHAR</td>
#       <td id="T_897f4_row13_col2" class="data row13 col2" >144604</td>
#       <td id="T_897f4_row13_col3" clas
#     <div style="
#         background: linear-gradient(135deg, #1a1a2e 0%, #16213e 100%);
#         padding: 12px 20px;
#         border-radius: 8px;
#         margin: 20px 0 10px 0;
#         border-left: 4px solid #e94560;
#     ">
#         <h3 style="color: #eee; margin: 0; font-weight: 600;">
#             🔢 Cardinality Analysis: data
#         </h3>
#     </div>
#             Column  Unique Values Uniqueness %                      Type
# 0            DR_NO        1003448       100.0%  🔑 Unique (potential key)
# 1        Date Rptd           1817         0.2%       📈 High (continuous)
# 2         DATE OCC           1817         0.2%       📈 High (continuous)
# 3         TIME OCC           1439         0.1%       📈 High (continuous)
# 4             AREA             21         0.0%       📈 High (continuous)
# 5        AREA NAME             21         0.0%       📈 High (continuous)
# 6      Rpt Dist No           1210         0.1%       📈 High (continuous)
# 7         Part 1-2              2         0.0%                  🔘 Binary
# 8           Crm Cd            140         0.0%       📈 High (continuous)
# 9      Crm Cd Desc            140         0.0%       📈 High (continuous)
# 10         Mocodes         310697        31.0%       📈 High (continuous)
# 11        Vict Age            104         0.0%       📈 High (continuous)
# 12        Vict Sex              5         0.0%       📊 Low (categorical)
# 13    Vict Descent             20         0.0%       📊 Low (categorical)
# 14       Premis Cd            314         0.0%       📈 High (continuous)
# 15     Premis Desc            306         0.0%       📈 High (continuous)
# 16  Weapon Used Cd             79         0.0%       📈 High (continuous)
# 17     Weapon Desc             79         0.0%       📈 High (continuous)
# 18          Status              6         0.0%       📊 Low (categorical)
# 19     Status Desc              6         0.0%       📊 Low (categorical)
# 20        Crm Cd 1            142         0.0%       📈 High (continuous)
# 21        Crm Cd 2            126         0.0%       📈 High (continuous)
# 22        Crm Cd 3             38         0.0%       📈 High (continuous)
# 23        Crm Cd 4              6         0.0%       📊 Low (categorical)
# 24        LOCATION          66548         6.6%       📈 High (continuous)
# 25    Cross Street          10405         1.0%       📈 High (continuous)
# 26             LAT           5425         0.5%       📈 High (continuous)
# 27             LON           4981         0.5%       📈 High (continuous)
#     <div style="
#         background: linear-gradient(135deg, #1a1a2e 0%, #16213e 100%);
#         padding: 12px 20px;
#         border-radius: 8px;
#         margin: 20px 0 10px 0;
#         border-left: 4px solid #e94560;
#     ">
#         <h3 style="color: #eee; margin: 0; font-weight: 600;">
#             🔗 Numeric Correlations: data
#         </h3>
#     </div>
# <style type="text/css">
# #T_897b9_row0_col0, #T_897b9_row1_col1, #T_897b9_row2_col2, #T_897b9_row2_col6, #T_897b9_row3_col3, #T_897b9_row4_col4, #T_897b9_row5_col5, #T_897b9_row6_col2, #T_897b9_row6_col6, #T_897b9_row7_col7, #T_897b9_row8_col8, #T_897b9_row9_col9, #T_897b9_row10_col10, #T_897b9_row11_col11 {
#   background-color: #1a472a;
#   color: white;
# }
# #T_897b9_row10_col11, #T_897b9_row11_col10 {
#   background-color: #4a1a1a;
#   color: white;
# }
# </style>
# <table id="T_897b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_897b9_level0_col0" class="col_heading level0 col0" >DR_NO</th>
#       <th id="T_897b9_level0_col1" class="col_heading level0 col1" >Part 1-2</th>
#       <th id="T_897b9_level0_col2" class="col_heading level0 col2" >Crm Cd</th>
#       <th id="T_897b9_level0_col3" class="col_heading level0 col3" >Vict Age</th>
#       <th id="T_897b9_level0_col4" class="col_heading level0 col4" >Premis Cd</th>
#       <th id="T_897b9_level0_col5" class="col_heading level0 col5" >Weapon Used Cd</th>
#       <th id="T_897b9_level0_col6" class="col_heading level0 col6" >Crm Cd 1</th>
#       <th id="T_897b9_level0_col7" class="col_heading level0 col7" >Crm Cd 2</th>
#       <th id="T_897b9_level0_col8" class="col_heading level0 col8" >Crm Cd 3</th>
#       <th id="T_897b9_level0_col9" class="col_heading level0 col9" >Crm Cd 4</th>
#       <th id="T_897b9_level0_col10" class="col_heading level0 col10" >LAT</th>
#       <th id="T_897b9_level0_col11" class="col_heading level0 col11" >LON</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_897b9_level0_row0" class="row_heading level0 row0" >DR_NO</th>
#       <td id="T_897b9_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_897b9_row0_col1" class="data row0 col1" >-0.039000</td>
#       <td id="T_897b9_row0_col2" class="data row0 col2" >-0.023000</td>
#       <td id="T_897b9_row0_col3" class="data row0 col3" >-0.068000</td>
#       <td id="T_897b9_row0_col4" class="data row0 col4" >0.025000</td>
#       <td id="T_897b9_row0_col5" class="data row0 col5" >0.018000</td>
#       <td id="T_897b9_row0_col6" class="data row0 col6" >-0.022000</td>
#       <td id="T_897b9_row0_col7" class="data row0 col7" >0.029000</td>
#       <td id="T_897b9_row0_col8" class="data row0 col8" >0.032000</td>
#       <td id="T_897b9_row0_col9" class="data row0 col9" >0.152000</td>
#       <td id="T_897b9_row0_col10" class="data row0 col10" >0.046000</td>
#       <td id="T_897b9_row0_col11" class="data row0 col11" >-0.045000</td>
#     </tr>
#     <tr>
#       <th id="T_897b9_level0_row1" class="row_heading level0 row1" >Part 1-2</th>
#       <td id="T_897b9_row1_col0" class="data row1 col0" >-0.039000</td>
#       <td id="T_897b9_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_897b9_row1_col2" class="data row1 col2" >0.698000</td>
#       <td id="T_897b9_row1_col3" class="data row1 col3" >0.206000</td>
#       <td id="T_897b9_row1_col4" class="data row1 col4" >0.280000</td>
#       <td id="T_897b9_row1_col5" class="data row1 col5" >0.426000</td>
#       <td id="T_897b9_row1_col6" class="data row1 col6" >0.699000</td>
#       <td id="T_897b9_row1_col7" class="data row1 col7" >0.076000</td>
#       <td id="T_897b9_row1_col8" class="data row1 col8" >0.009000</td>
#       <td id="T_897b9_row1_col9" class="data row1 col9" >0.104000</td>
#       <td id="T_897b9_row1_col10" class="data row1 col10" >-0.029000</td>
#       <td id="T_897b9_row1_col11" class="data row1 col11" >0.029000</td>
#     </tr>
#     <tr>
#       <th id="T_897b9_level0_row2" class="row_heading level0 row2" >Crm Cd</th>
#       <td id="T_897b9_row2_col0" class="data row2 col0" >-0.023000</td>
#       <td id="T_897b9_row2_col1" class="data row2 col1" >0.698000</td>
#       <td id="T_897b9_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_897b9_row2_col3" class="data row2 col3" >-0.021000</td>
#       <td id="T_897b9_row2_col4" class="data row2 col4" >0.118000</td>
#       <td id="T_897b9_row2_col5" class="data row2 col5" >0.366000</td>
#       <td id="T_897b9_row2_col6" class="data row2 col6" >0.999000</td>
#       <td id="T_897b9_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_897b9_row2_col8" class="data row2 col8" >0.121000</td>
#       <td id="T_897b9_row2_col9" class="data row2 col9" >0.037000</td>
#       <td id="T_897b9_row2_col10" class="data row2 col10" >-0.039000</td>
#       <td id="T_897b9_row2_col11" class="data row2 col11" >0.039000</td>
#     </tr>
#     <tr>
#       <th id="T_897b9_level0_row3" class="row_heading level0 row3" >Vict Age</th>
#       <td id="T_897b9_row3_col0" class="data row3 col0" >-0.068000</td>
#       <td id="T_897b9_row3_col1" class="data row3 col1" >0.206000</td>
#       <td id="T_897b9_row3_col2" class="data row3 col2" >-0.021000</td>
#       <td id="T_897b9_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_897b9_row3_col4" class="data row3 col4" >0.187000</td>
#       <td id="T_897b9_row3_col5" class="data row3 col5" >0.082000</td>
#       <td id="T_897b9_row3_col6" class="data row3 col6" >-0.021000</td>
#       <td id="T_897b9_row3_col7" class="data row3 col7" >-0.023000</td>
#       <td id="T_897b9_row3_col8" class="data row3 col8" >-0.011000</td>
#       <td id="T_897b9_row3_col9" class="data row3 col9" >-0.004000</td>
#       <td id="T_897b9_row3_col10" class="data row3 col10" >-0.001000</td>
#       <td id="T_897b9_row3_col11" class="data row3 col11" >0.002000</td>
#     </tr>
#     <tr>
#       <th id="T_897b9_level0_row4" class="row_heading level0 row4" >Premis Cd</th>
#       <td id="T_897b9_row4_col0" class="data row4 col0" >0.025000</td>
#       <td id="T_897b9_row4_col1" class="data row4 col1" >0.280000</td>
#       <td id="T_897b9_row4_col2" class="data row4 col2" >0.118000</td>
#       <td id="T_897b9_row4_col3" class="data row4 col3" >0.187000</td>
#       <td id="T_897b9_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_897b9_row4_col5" class="data row4 col5" >0.205000</td>
#       <td id="T_897b9_row4_col6" class="data row4 col6" >0.118000</td>
#       <td id="T_897b9_row4_col7" class="data row4 col7" >-0.055000</td>
#       <td id="T_897b9_row4_col8" class="data row4 col8" >-0.010000</td>
#       <td id="T_897b9_row4_col9" class="data row4 col9" >-0.002000</td>
#       <td id="T_897b9_row4_col10" class="data row4 col10" >-0.006000</td>
#       <td id="T_897b9_row4_col11" class="data row4 col11" >0.007000</td>
#     </tr>
#     <tr>
#       <th id="T_897b9_level0_row5" class="row_heading level0 row5" >Weapon Used Cd</th>
#       <td id="T_897b9_row5_col0" class="data row5 col0" >0.018000</td>
#       <td id="T_897b9_row5_col1" class="data row5 col1" >0.426000</td>
#       <td id="T_897b9_row5_col2" class="data row5 col2" >0.366000</td>
#       <td id="T_897b9_row5_col3" class="data row5 col3" >0.082000</td>
#       <td id="T_897b9_row5_col4" class="data row5 col4" >0.205000</td>
#       <td id="T_897b9_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_897b9_row5_col6" class="data row5 col6" >0.367000</td>
#       <td id="T_897b9_row5_col7" class="data row5 col7" >-0.146000</td>
#       <td id="T_897b9_row5_col8" class="data row5 col8" >-0.061000</td>
#       <td id="T_897b9_row5_col9" class="data row5 col9" >0.029000</td>
#       <td id="T_897b9_row5_col10" class="data row5 col10" >-0.009000</td>
#       <td id="T_897b9_row5_col11" class="data row5 col11" >0.011000</td>
#     </tr>
#     <tr>
#       <th id="T_897b9_level0_row6" class="row_heading level0 row6" >Crm Cd 1</th>
#       <td id="T_897b9_row6_col0" class="data row6 col0" >-0.022000</td>
#       <td id="T_897b9_row6_col1" class="data row6 col1" >0.699000</td>
#       <td id="T_897b9_row6_col2" class="data row6 col2" >0.999000</td>
#       <td id="T_897b9_row6_col3" class="data row6 col3" >-0.021000</td>
#       <td id="T_897b9_row6_col4" class="data row6 col4" >0.118000</td>
#       <td id="T_897b9_row6_col5" class="data row6 col5" >0.367000</td>
#       <td id="T_897b9_row6_col6" class="data row6 col6" >1.000000</td>
#       <td id="T_897b9_row6_col7" class="data row6 col7" >0.021000</td>
#       <td id="T_897
#     <div style="
#         background: linear-gradient(135deg, #1a1a2e 0%, #16213e 100%);
#         padding: 12px 20px;
#         border-radius: 8px;
#         margin: 20px 0 10px 0;
#         border-left: 4px solid #e94560;
#     ">
#         <h3 style="color: #eee; margin: 0; font-weight: 600;">
#             ✅ Analysis Complete!
#         </h3>
#     </div>

# %% [markdown]
# ## Individual Analysis Methods
#
# Use these cells to run specific analyses as needed.

# %%
# View value distribution for a specific column
# eda.value_counts("column_name")

# %%
# Run custom SQL queries
# eda.query("SELECT * FROM data WHERE column > 100")

# %% [markdown]
# ## Quick One-Liner Alternative
#
# If you just need a fast summary without all the styling, use DuckDB's built-in SUMMARIZE:

# %%
# Quick summary using raw DuckDB (uncomment to use)
duckdb.sql(f"SUMMARIZE SELECT * FROM '{DATA_SOURCE}'").show()
# Out:
# ┌──────────────┬─────────────┬─────────────────────────────────┬─────────────────────────────────┬───────────────┬────────────────────────────┬────────────────────┬────────────────────────────┬────────────────────────────┬────────────────────────────┬─────────┬─────────────────┐
# │ column_name  │ column_type │               min               │               max               │ approx_unique │            avg             │        std         │            q25             │            q50             │            q75             │  count  │ null_percentage │
# │   varchar    │   varchar   │             varchar             │             varchar             │     int64     │          varchar           │      varchar       │          varchar           │          varchar           │          varchar           │  int64  │  decimal(9,2)   │
# ├──────────────┼─────────────┼─────────────────────────────────┼─────────────────────────────────┼───────────────┼────────────────────────────┼────────────────────┼────────────────────────────┼────────────────────────────┼────────────────────────────┼─────────┼─────────────────┤
# │ DR_NO        │ BIGINT      │ 817                             │ 249928885                       │       1324249 │ 220185515.9817868          │ 13169630.316388853 │ 210635752                  │ 220938202                  │ 231095914                  │ 1003448 │            0.00 │
# │ Date Rptd    │ TIMESTAMP   │ 2020-01-01 00:00:00             │ 2024-12-21 00:00:00             │          2115 │ 2022-05-24 10:56:48.707576 │ NULL               │ 2021-04-21 13:35:57.197728 │ 2022-06-05 18:21:49.368824 │ 2023-07-02 01:03:14.985018 │ 1003448 │            0.00 │
# │ DATE OCC     │ TIMESTAMP   │ 2020-01-01 00:00:00             │ 2024-12-21 00:00:00             │          2115 │ 2022-05-12 07:53:05.958814 │ NULL               │ 2021-04-06 07:39:35.119392 │ 2022-05-25 19:31:06.705962 │ 2023-06-18 13:56:38.173008 │ 1003448 │            0.00 │
# │ TIME OCC     │ VARCHAR     │ 0001                            │ 2359                            │          1649 │ NULL                       │ NULL               │ NULL                       │ NULL                       │ NULL                       │ 1003448 │            0.00 │
# │ AREA         │ VARCHAR     │ 01                              │ 21                              │            21 │ NULL                       │ NULL               │ NULL                       │ NULL                       │ NULL                       │ 1003448 │            0.00 │
# │ AREA NAME    │ VARCHAR     │ 77th Street                     │ Wilshire                        │            21 │ NULL                       │ NULL               │ NULL                       │ NULL                       │ NULL                       │ 1003448 │            0.00 │
# │ Rpt Dist No  │ VARCHAR     │ 0101                            │ 2199                            │          1805 │ NULL                       │ NULL               │ NULL                       │ NULL                       │ NULL                       │ 1003448 │            0.00 │
# │ Part 1-2     │ BIGINT      │ 1                               │ 2                               │             2 │ 1.4005259863988966         │ 0.4900052651739673 │ 1                          │ 1                          │ 2                          │ 1003448 │            0.00 │
# │ Crm Cd       │ BIGINT      │ 110                             │ 956                             │           148 │ 500.2210418477091          │ 205.3108756269526  │ 331                        │ 444                        │ 626                        │ 1003448 │            0.00 │
# │ Crm Cd Desc  │ VARCHAR     │ ARSON                           │ WEAPONS POSSESSION/BOMBING      │           140 │ NULL                       │ NULL               │ NULL                       │ NULL                       │ NULL                       │ 1003448 │            0.00 │
# │   ·          │    ·        │ ·                               │ ·                               │             · │  ·                         │  ·                 │  ·                         │  ·                         │  ·                         │    ·    │              ·  │
# │   ·          │    ·        │ ·                               │ ·                               │             · │  ·                         │  ·                 │  ·                         │  ·                         │  ·                         │    ·    │              ·  │
# │   ·          │    ·        │ ·                               │ ·                               │             · │  ·                         │  ·                 │  ·                         │  ·                         │  ·                         │    ·    │              ·  │
# │ Status       │ VARCHAR     │ AA                              │ JO                              │             5 │ NULL                       │ NULL               │ NULL                       │ NULL                       │ NULL                       │ 1003448 │            0.00 │
# │ Status Desc  │ VARCHAR     │ Adult Arrest                    │ UNK                             │             6 │ NULL                       │ NULL               │ NULL                       │ NULL                       │ NULL                       │ 1003448 │            0.00 │
# │ Crm Cd 1     │ BIGINT      │ 110                             │ 956                             │           148 │ 499.98124246963187         │ 205.11125919585243 │ 331                        │ 444                        │ 626                        │ 1003448 │            0.00 │
# │ Crm Cd 2     │ BIGINT      │ 210                             │ 999                             │           122 │ 958.1182325877485          │ 110.36480208619128 │ 998                        │ 998                        │ 998                        │ 1003448 │           93.11 │
# │ Crm Cd 3     │ BIGINT      │ 310                             │ 999                             │            43 │ 984.022030237581           │ 52.340476149782475 │ 998                        │ 998                        │ 998                        │ 1003448 │           99.77 │
# │ Crm Cd 4     │ BIGINT      │ 821                             │ 999                             │             6 │ 991.21875                  │ 27.069850123602198 │ 998                        │ 998                        │ 998                        │ 1003448 │           99.99 │
# │ LOCATION     │ VARCHAR     │ 00    17TH                      │ ZOO                          DR │         92438 │ NULL                       │ NULL               │ NULL                       │ NULL                       │ NULL                       │ 1003448 │            0.00 │
# │ Cross Street │ VARCHAR     │ 10                           FY │ ZUNIGA                       LN │         13183 │ NULL                       │ NULL               │ NULL                       │ NULL                       │ NULL                       │ 1003448 │           84.64 │
# │ LAT          │ DOUBLE      │ 0.0                             │ 34.3343                         │          5586 │ 33.99809729751689          │ 1.6119417110745993 │ 34.01474418541793          │ 34.05881085604564          │ 34.16399182549716          │ 1003448 │            0.00 │
# │ LON          │ DOUBLE      │ -118.6676                       │ 0.0                             │          6665 │ -118.09045798745984        │ 5.586664867774905  │ -118.43023997201503        │ -118.32273815942757        │ -118.27427751911966        │ 1003448 │            0.00 │
# ├──────────────┴─────────────┴─────────────────────────────────┴─────────────────────────────────┴───────────────┴────────────────────────────┴────────────────────┴────────────────────────────┴────────────────────────────┴────────────────────────────┴─────────┴─────────────────┤
# │ 28 rows (20 shown)                                                                                                                                                                                                                                                       12 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## Cleanup

# %%
# Close the connection when done (optional)
# eda.close()
